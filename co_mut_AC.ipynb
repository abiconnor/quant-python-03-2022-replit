# %% [markdown]
# <a href="https://colab.research.google.com/github/abiconnor/quant-python-03-2022-replit/blob/main/co_mut_AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install comut
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.3/332.3 kB 5.5 MB/s eta 0:00:00
# ...

# %%
# !pip install pandas

# %%
from comut import comut
from comut import fileparsers

# %%
import pandas as pd

# %%
data = pd.read_csv('co_mut_data200324.csv')
data.head(2)
# Out:
#                                               sample category  \
# 0  10_1D_S26_e_final.bam_FMC_annotated.vcf.hg38_m...     KRAS
# 1  10_1D_S26_e_final.bam_FMC_annotated.vcf.hg38_m...      RB1
#
#                value
# 0  nonsynonymous SNV
# 1           intronic

# %%
my_first_comut = comut.CoMut()
my_first_comut.add_categorical_data(data, name = 'Mutation type')
my_first_comut.plot_comut(figsize = (10,3))
my_first_comut.add_unified_legend()

# %%
indicator_df = pd.read_csv('multifocal_groups.csv')
indicator_df.head()
# Out:
#                                               sample  group
# 0  10_1D_S26_e_final.bam_FMC_annotated.vcf.hg38_m...      1
# 1  13_1D_S2_e_final.bam_FMC_annotated.vcf.hg38_mu...      2
# 2  14_1D_S4_e_final.bam_FMC_annotated.vcf.hg38_mu...      3
# 3  17_1D_S28_e_final.bam_FMC_annotated.vcf.hg38_m...      4
# 4  220_1_e_final.bam_FMC_annotated.vcf.hg38_multi...      5

# %%
# add indicators first, since they will be at the bottom
indicator_kwargs = {'color': 'black', 'marker': 'o', 'linewidth': 2, 'markersize': 5}

# %%
my_second_comut = comut.CoMut()
my_second_comut.add_sample_indicators(indicator_df, name = 'Same patient', plot_kwargs = indicator_kwargs)
my_second_comut.add_categorical_data(data, name = 'Mutation type')
my_second_comut.plot_comut(figsize = (10,3), x_padding = 0.04, y_padding = 0.04, tri_padding = 0.03, hspace = 0.05)
my_second_comut.add_unified_legend()

# %%
my_second_comut = comut.CoMut()
my_second_comut.add_sample_indicators(indicator_df, name = 'Same patient', plot_kwargs = indicator_kwargs)
my_second_comut.add_categorical_data(data, name = 'Mutation type')
my_second_comut.plot_comut(figsize = (10,3), x_padding = 0.04, y_padding = 0.04, tri_padding = 0.03, hspace = 0.05)
my_second_comut.add_unified_legend()

# %%
bar_kwargs = {'width': 0.8}

# %%
mut_burden_df = pd.read_csv('sample_neoTMB.csv')
mut_burden_df.head(3)
# Out:
#                                               sample  neoTMB (mut/Mb)
# 0  10_1D_S26_e_final.bam_FMC_annotated.vcf.hg38_m...        39.918033
# 1  13_1D_S2_e_final.bam_FMC_annotated.vcf.hg38_mu...        16.584699
# 2  14_1D_S4_e_final.bam_FMC_annotated.vcf.hg38_mu...        30.054645

# %%
my_second_comut.add_bar_data(mut_burden_df, name = 'neoTMB', bar_kwargs = bar_kwargs,
                       ylabel = 'neoTMB\n(mut/Mb)')
my_second_comut.plot_comut(figsize = (14, 8), x_padding = 0.05, y_padding = 0.04, tri_padding = 0.03, hspace = 0.08, subplot_hspace = 0.01, wspace = 0.1)
my_second_comut.add_unified_legend()
my_second_comut.axes['Same patient'].set_xticklabels([])
# Out:
# [Text(0.5, 0, ''),
#  Text(1.5, 0, ''),
#  Text(2.5, 0, ''),
#  Text(3.5, 0, ''),
#  Text(4.5, 0, ''),
#  Text(5.5, 0, ''),
#  Text(6.5, 0, ''),
#  Text(7.5, 0, ''),
#  Text(8.5, 0, ''),
#  Text(9.5, 0, ''),
#  Text(10.5, 0, ''),
#  Text(11.5, 0, ''),
#  Text(12.5, 0, ''),
#  Text(13.5, 0, ''),
#  Text(14.5, 0, ''),
#  Text(15.5, 0, ''),
#  Text(16.5, 0, ''),
#  Text(17.5, 0, ''),
#  Text(18.5, 0, ''),
#  Text(19.5, 0, ''),
#  Text(20.5, 0, ''),
#  Text(21.5, 0, ''),
#  Text(22.5, 0, ''),
#  Text(23.5, 0, ''),
#  Text(24.5, 0, ''),
#  Text(25.5, 0, ''),
#  Text(26.5, 0, ''),
#  Text(27.5, 0, ''),
#  Text(28.5, 0, ''),
#  Text(29.5, 0, ''),
#  Text(30.5, 0, ''),
#  Text(31.5, 0, ''),
#  Text(32.5, 0, ''),
#  Text(33.5, 0, ''),
#  Text(34.5, 0, ''),
#  Text(35.5, 0, ''),
#  Text(36.5, 0, ''),
#  Text(37.5, 0, ''),
#  Text(38.5, 0, ''),
#  Text(39.5, 0, ''),
#  Text(40.5, 0, ''),
#  Text(41.5, 0, ''),
#  Text(42.5, 0, ''),
#  Text(43.5, 0, ''),
#  Text(44.5, 0, ''),
# ...

# %%
my_second_comut.add_bar_data(mut_burden_df, name = 'neoTMB', bar_kwargs = bar_kwargs,
                       ylabel = 'neoTMB\n(mut/Mb)')
my_second_comut.plot_comut(figsize = (14, 8), x_padding = 0.05, y_padding = 0.04, tri_padding = 0.03, hspace = 0.08, subplot_hspace = 0.01, wspace = 0.1)
my_second_comut.add_unified_legend()

# %%
aetiology_df = pd.read_csv('sample_aetiologies.csv')
aetiology_df.head(3)
# Out:
#                                               sample   category  value
# 0  10_1D_S26_e_final.bam_FMC_annotated.vcf.hg38_m...  Aetiology  NAFLD
# 1  13_1D_S2_e_final.bam_FMC_annotated.vcf.hg38_mu...  Aetiology  NAFLD
# 2  14_1D_S4_e_final.bam_FMC_annotated.vcf.hg38_mu...  Aetiology  NAFLD

# %%
ignored_values = []
border_white = ['Absent']
rename = {'Absent': 'Wild type'}

# %%
my_second_comut.add_categorical_data(aetiology_df, name = 'Aetiology')
my_second_comut.plot_comut(figsize = (14, 8), x_padding = 0.05, y_padding = 0.04, tri_padding = 0.03, hspace = 0.08, subplot_hspace = 0.01, wspace = 0.1)
if my_second_comut.axes['Mutation type'].get_legend() is not None:
    my_second_comut.axes['Mutation type'].get_legend().remove()
my_second_comut.axes['Same patient'].set_xticklabels([])

aetiology_leg = my_second_comut.add_axis_legend(name = 'Aetiology', bbox_to_anchor = (1, 3), title = 'Aetiology', ncol = 2, columnspacing = 0.5)
mut_leg = my_second_comut.add_axis_legend(name = 'Mutation type', bbox_to_anchor = (1, 0.7), title = 'Mutation type', ncol = 2,ignored_values = ignored_values, rename = rename,
                             border_white = border_white)

# %%
gene_order = ['RB1','TSC2','TP53','PTEN','AXIN1','BRD7','CTNNB1','ALB','TERT','KEAP1','ARID1A','ACVR2A','NFE2L2','KRAS','ARID1B','CDKN2A','BAP1']

# %%
my_second_comut.add_categorical_data(aetiology_df, name = 'Aetiology')
my_second_comut.add_categorical_data(data, name = 'Mutation type', category_order = gene_order)
my_second_comut.plot_comut(figsize = (14, 8), x_padding = 0.05, y_padding = 0.04, tri_padding = 0.03, hspace = 0.08, subplot_hspace = 0.01, wspace = 0.1)
if my_second_comut.axes['Mutation type'].get_legend() is not None:
    my_second_comut.axes['Mutation type'].get_legend().remove()
my_second_comut.axes['Same patient'].set_xticklabels([])

aetiology_leg = my_second_comut.add_axis_legend(name = 'Aetiology', bbox_to_anchor = (1,3), title = 'Aetiology', ncol = 2, columnspacing = 0.5)
mut_leg = my_second_comut.add_axis_legend(name = 'Mutation type', bbox_to_anchor = (1, 0.7), title = 'Mutation type', ncol = 2,ignored_values = ignored_values, rename = rename,
                             border_white = border_white)
same_patient_leg = my_second_comut.add_axis_legend(name = 'Same patient', bbox_to_anchor = (1, 1.2))

# %%
structure = [['Aetiology'],['Same patient'],['Mutation type'] ,['neoTMB'] ]

# %%
my_second_comut.add_categorical_data(aetiology_df, name = 'Aetiology')
my_second_comut.add_categorical_data(data, name = 'Mutation type', category_order = gene_order)
my_second_comut.plot_comut(figsize = (14, 8), x_padding = 0.05, y_padding = 0.04, tri_padding = 0.03, hspace = 0.08, subplot_hspace = 0.01, wspace = 0.1, structure = structure)
if my_second_comut.axes['Mutation type'].get_legend() is not None:
    my_second_comut.axes['Mutation type'].get_legend().remove()
my_second_comut.axes['Same patient'].set_xticklabels([])

aetiology_leg = my_second_comut.add_axis_legend(name = 'Aetiology', bbox_to_anchor = (1,1), title = 'Aetiology', ncol = 2, columnspacing = 0.5)
mut_leg = my_second_comut.add_axis_legend(name = 'Mutation type', bbox_to_anchor = (1, 0.7), title = 'Mutation type', ncol = 2,ignored_values = ignored_values, rename = rename,
                             border_white = border_white)
same_patient_leg = my_second_comut.add_axis_legend(name = 'Same patient', bbox_to_anchor = (1, 1.2))

# %%
gene_mutation_freq = pd.read_csv("gene_mutation_freq.csv")
bar_kwargs = {'height': 0.8}
gene_mutation_freq.head(3)
# Out:
#   category  Frequency
# 0     BAP1     0.0189
# 1   CDKN2A     0.0377
# 2   ARID1B     0.1132

# %%
gene_mutation_list = list(gene_mutation_freq)
gene_mutation_list.head(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-114-25ec98873c6b> in <cell line: 2>()
#       1 gene_mutation_list = list(gene_mutation_freq)
# ----> 2 gene_mutation_list.head(3)
#
# AttributeError: 'list' object has no attribute 'head'

# %%
side_mapping = {'Frequency': 'darkgrey'}
bar_kwargs = {'height': 0.8}

# %%
#trying to add mutation frequency as a side bar but error about indexer?
my_second_comut.add_side_bar_data(gene_mutation_freq, paired_name = 'Mutation type', name = 'Frequency', mapping = side_mapping,
                                  xlabel = 'Mutation frequency (% tumours)', position = 'left', bar_kwargs = bar_kwargs)
my_second_comut.plot_comut(figsize = (14, 8), x_padding = 0.05, y_padding = 0.04, tri_padding = 0.03, hspace = 0.08, subplot_hspace = 0.01, wspace = 0.1)
if my_second_comut.axes['Mutation type'].get_legend() is not None:
    my_second_comut.axes['Mutation type'].get_legend().remove()
my_second_comut.axes['Same patient'].set_xticklabels([])

aetiology_leg = my_second_comut.add_axis_legend(name = 'Aetiology', bbox_to_anchor = (1, 3), title = 'Aetiology', ncol = 2, columnspacing = 0.5)
mut_leg = my_second_comut.add_axis_legend(name = 'Mutation type', bbox_to_anchor = (1, 0.7), title = 'Mutation type', ncol = 2,ignored_values = ignored_values, rename = rename,
                             border_white = border_white)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-140-29e508578193> in <cell line: 2>()
#       1 #trying to add mutation frequency as a side bar but error about indexer
# ----> 2 my_second_comut.add_side_bar_data(gene_mutation_freq, paired_name = 'Mutation type', name = 'Frequency', mapping = side_mapping,
#       3                                   xlabel = 'Mutation frequency (% tumours)', position = 'left', bar_kwargs = bar_kwargs)
#       4 my_second_comut.plot_comut(figsize = (14, 8), x_padding = 0.05, y_padding = 0.04, tri_padding = 0.03, hspace = 0.08, subplot_hspace = 0.01, wspace = 0.1)
#       5 if my_second_comut.axes['Mutation type'].get_legend() is not None:
#
# /usr/local/lib/python3.10/dist-packages/comut/comut.py in add_side_bar_data(self, data, paired_name, name, position, mapping, stacked, xlabel, bar_kwargs)
# ...

# %%
#trying to add mutation frequency as a side bar but error when I convert indexer to list...
my_second_comut.add_categorical_data(aetiology_df, name = 'Aetiology')
my_second_comut.add_categorical_data(data, name = 'Mutation type', category_order = gene_order)
my_second_comut.add_side_bar_data(gene_mutation_list, paired_name = 'Mutation type', name = 'Frequency', xlabel = 'Mutation frequency (% tumours)', position = 'left', bar_kwargs = bar_kwargs)
my_second_comut.plot_comut(figsize = (14, 8), x_padding = 0.05, y_padding = 0.04, tri_padding = 0.03, hspace = 0.08, subplot_hspace = 0.01, wspace = 0.1)
if my_second_comut.axes['Mutation type'].get_legend() is not None:
    my_second_comut.axes['Mutation type'].get_legend().remove()
my_second_comut.axes['Same patient'].set_xticklabels([])

aetiology_leg = my_second_comut.add_axis_legend(name = 'Aetiology', bbox_to_anchor = (1, 3), title = 'Aetiology', ncol = 2, columnspacing = 0.5)
mut_leg = my_second_comut.add_axis_legend(name = 'Mutation type', bbox_to_anchor = (1, 0.7), title = 'Mutation type', ncol = 2,ignored_values = ignored_values, rename = rename,
                             border_white = border_white)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-116-664dcc66ba39> in <cell line: 4>()
#       2 my_second_comut.add_categorical_data(aetiology_df, name = 'Aetiology')
#       3 my_second_comut.add_categorical_data(data, name = 'Mutation type', category_order = gene_order)
# ----> 4 my_second_comut.add_side_bar_data(gene_mutation_list, paired_name = 'Mutation type', name = 'Frequency', xlabel = 'Mutation frequency (% tumours)', position = 'left', bar_kwargs = bar_kwargs)
#       5 my_second_comut.plot_comut(figsize = (14, 8), x_padding = 0.05, y_padding = 0.04, tri_padding = 0.03, hspace = 0.08, subplot_hspace = 0.01, wspace = 0.1)
#       6 if my_second_comut.axes['Mutation type'].get_legend() is not None:
#
# /usr/local/lib/python3.10/dist-packages/comut/comut.py in add_side_bar_data(self, data, paired_name, name, position, mapping, stacked, xlabel, bar_kwargs)
# ...

# %%
sample_ki_67 = pd.read_csv("sample_ki_67.csv")
sample_ki_67.head(3)
# Out:
#                                               sample category  value
# 0  10_1D_S26_e_final.bam_FMC_annotated.vcf.hg38_m...    Ki-67   5.68
# 1  13_1D_S2_e_final.bam_FMC_annotated.vcf.hg38_mu...    Ki-67   4.79
# 2  14_1D_S4_e_final.bam_FMC_annotated.vcf.hg38_mu...    Ki-67   4.64

# %%
value_range = (0,26.6)

# %%
cat_mapping = {'Not Available': {'facecolor': 'red'}}

# %%
my_second_comut.add_continuous_data(sample_ki_67, name = 'Ki-67', mapping = "Purples", cat_mapping = cat_mapping, value_range = value_range)
my_second_comut.plot_comut()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-120-babf7f719cc5> in <cell line: 2>()
#       1 my_second_comut.add_continuous_data(sample_ki_67, name = 'Ki-67', mapping = "Purples", cat_mapping = cat_mapping, value_range = value_range)
# ----> 2 my_second_comut.plot_comut()
#
# /usr/local/lib/python3.10/dist-packages/comut/comut.py in plot_comut(self, fig, spec, x_padding, y_padding, tri_padding, heights, hspace, subplot_hspace, widths, wspace, structure, figsize)
#    1496                 plot_name = plot[0]
#    1497                 ax = fig.add_subplot(spec[num_subplots - i - 1, comut_idx], sharex=sharex)
# -> 1498                 ax = self._plot_data_on_axis(ax=ax, plot_name=plot_name, x_padding=x_padding, y_padding=y_padding, tri_padding=tri_padding)
#    1499
#    1500                 # extract all sideplots on this axis
#
# ...
